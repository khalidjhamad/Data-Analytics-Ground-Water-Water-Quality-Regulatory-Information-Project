# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv("cleaned_data.csv", encoding='latin1')
df
# Out:
#                 COUNTY              CASE_TYPE                       STATUS  \
# 0             Monterey  Military Cleanup Site  Open - Long Term Management
# 1               Sonoma   Cleanup Program Site           Open - Remediation
# 2      San Luis Obispo                * NPDES                       Active
# 3               Merced      LUST Cleanup Site       Open - Site Assessment
# 4          Santa Clara   Cleanup Program Site       Open - Site Assessment
# ...                ...                    ...                          ...
# 75058       Stanislaus   Cleanup Program Site              Open - Inactive
# 75059        San Diego  Military Cleanup Site      Completed - Case Closed
# 75060        Mendocino      LUST Cleanup Site      Completed - Case Closed
# 75061        San Diego      Military UST Site      Completed - Case Closed
# 75062        San Diego      LUST Cleanup Site      Completed - Case Closed
#
#       STATUS_DATE                                CLAIM_STATUS  \
# ...

# %%
df['MILITARY_DOD_SITE'].value_counts().plot(kind='bar');

# %%
df[['CALENVIROSCREEN3_SCORE', 'CALENVIROSCREEN4_SCORE']].head(9)
# Out:
#   CALENVIROSCREEN3_SCORE    CALENVIROSCREEN4_SCORE
# 0                 41-45%                    45-50%
# 1                 21-25%                    20-25%
# 2                 16-20%                    35-40%
# 3                 91-95%  95-100% (highest scores)
# 4                 36-40%                    35-40%
# 5                 76-80%                    80-85%
# 6                 81-85%                    80-85%
# 7                 21-25%                    40-45%
# 8                 66-70%                    70-75%

# %%
df[['CALENVIROSCREEN4_SCORE', 'RWQCB_REGION']].sort_values(by='CALENVIROSCREEN4_SCORE',ascending=False).head(10)
# Out:
#          CALENVIROSCREEN4_SCORE                      RWQCB_REGION
# 46249  95-100% (highest scores)      LOS ANGELES RWQCB (REGION 4)
# 14836  95-100% (highest scores)        SANTA ANA RWQCB (REGION 8)
# 70066  95-100% (highest scores)        SANTA ANA RWQCB (REGION 8)
# 14804  95-100% (highest scores)  CENTRAL VALLEY RWQCB (REGION 5S)
# 70070  95-100% (highest scores)  CENTRAL VALLEY RWQCB (REGION 5F)
# 14812  95-100% (highest scores)  CENTRAL VALLEY RWQCB (REGION 5F)
# 60468  95-100% (highest scores)      LOS ANGELES RWQCB (REGION 4)
# 60465  95-100% (highest scores)      LOS ANGELES RWQCB (REGION 4)
# 40162  95-100% (highest scores)        SANTA ANA RWQCB (REGION 8)
# 14822  95-100% (highest scores)        SANTA ANA RWQCB (REGION 8)

# %%
df[['CALENVIROSCREEN4_SCORE', 'RWQCB_REGION']].sort_values(by='CALENVIROSCREEN4_SCORE',ascending=True).head(10)
# Out:
#       CALENVIROSCREEN4_SCORE                        RWQCB_REGION
# 37533   1-5% (lowest scores)          SAN DIEGO RWQCB (REGION 9)
# 61835   1-5% (lowest scores)  SAN FRANCISCO BAY RWQCB (REGION 2)
# 61841   1-5% (lowest scores)  SAN FRANCISCO BAY RWQCB (REGION 2)
# 19652   1-5% (lowest scores)          SAN DIEGO RWQCB (REGION 9)
# 47674   1-5% (lowest scores)  SAN FRANCISCO BAY RWQCB (REGION 2)
# 39915   1-5% (lowest scores)  SAN FRANCISCO BAY RWQCB (REGION 2)
# 61867   1-5% (lowest scores)  SAN FRANCISCO BAY RWQCB (REGION 2)
# 71242   1-5% (lowest scores)  SAN FRANCISCO BAY RWQCB (REGION 2)
# 7382    1-5% (lowest scores)  SAN FRANCISCO BAY RWQCB (REGION 2)
# 39931   1-5% (lowest scores)          LAHONTAN RWQCB (REGION 6T)

# %%
highscores_data = {
    "CALENVIROSCREEN4_SCORE": [
        46249, 14836, 70066, 14804, 70070,
        14812, 60468, 60465, 40162, 14822
    ],
    "RWQCB_REGION": [
        "LOS ANGELES RWQCB (REGION 4)",
        "SANTA ANA RWQCB (REGION 8)",
        "SANTA ANA RWQCB (REGION 8)",
        "CENTRAL VALLEY RWQCB (REGION 5S)",
        "CENTRAL VALLEY RWQCB (REGION 5F)",
        "CENTRAL VALLEY RWQCB (REGION 5F)",
        "LOS ANGELES RWQCB (REGION 4)",
        "LOS ANGELES RWQCB (REGION 4)",
        "SANTA ANA RWQCB (REGION 8)",
        "SANTA ANA RWQCB (REGION 8)"
    ]
}


df=pd.DataFrame(data)

region_counts=df['RWQCB_REGION'].value_counts()


region_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Number of (95–100% )CalEnviroScreen per RWQCB Region')
plt.xlabel('RWQCB Region')
plt.ylabel('Number of Tracts')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
lowscore_data = {
    "CALENVIROSCREEN4_SCORE": [
        37533, 61835, 61841, 19652, 47674,
        39915, 61867, 71242, 7382, 39931
    ],
    "RWQCB_REGION": [
        "SAN DIEGO RWQCB (REGION 9)",
        "SAN FRANCISCO BAY RWQCB (REGION 2)",
        "SAN FRANCISCO BAY RWQCB (REGION 2)",
        "SAN DIEGO RWQCB (REGION 9)",
        "SAN FRANCISCO BAY RWQCB (REGION 2)",
        "SAN FRANCISCO BAY RWQCB (REGION 2)",
        "SAN FRANCISCO BAY RWQCB (REGION 2)",
        "SAN FRANCISCO BAY RWQCB (REGION 2)",
        "SAN FRANCISCO BAY RWQCB (REGION 2)",
        "LAHONTAN RWQCB (REGION 6T)"
    ]
}

df_low = pd.DataFrame(lowscore_data)


low_counts = df_low['RWQCB_REGION'].value_counts()

low_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('RWQCB Regions with Lowest (1–5%) CalEnviroScreen Scores')
plt.xlabel('RWQCB Region')
plt.ylabel('Number of Tracts')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
